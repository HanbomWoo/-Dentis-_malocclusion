# %%
import os
import numpy
from stl import mesh
from mpl_toolkits import mplot3d
from matplotlib import pyplot as plt
import vtkplotlib as vpl

import glob
import pprint
from tqdm import tqdm
from sklearn.utils import Bunch

from IPython import display
import ipywidgets as widgets

# %matplotlib inline
from matplotlib import pyplot as plt
plt.style.use('seaborn-white')
import numpy as np
import pandas as pd
import seaborn as sns
sns.set_style('white')

import cv2 as cv

# %%
data_path_root = './data/'

data_paths_deid = glob.glob(os.path.join(data_path_root, r'*_DeID'))
data_paths_deid = sorted(data_paths_deid)

print(data_paths_deid)
#jin_utils.print_paths(data_paths_deid)

data_paths_diorco = glob.glob(os.path.join(data_path_root, r'*_Diorco'))
data_paths_diorco = sorted(data_paths_diorco)

print(data_paths_diorco)
#jin_utils.print_paths(data_paths_diorco)

label_paths = glob.glob(os.path.join(data_path_root, '*_DeID/label*'))
label_paths = sorted(label_paths)

print(label_paths)
#jin_utils.print_paths(label_paths)
# Out:
# ['./data\\data_KNU_2020-08-14_DeID', './data\\data_KNU_2020-09-17_DeID']
# ['./data\\data_KNU_2020-08-14_Diorco', './data\\data_KNU_2020-09-17_Diorco']
# ['./data\\data_KNU_2020-08-14_DeID\\label.xlsx', './data\\data_KNU_2020-09-17_DeID\\label.xlsx']

# %%
data_paths_deid
# Out:
# ['./data\\data_KNU_2020-08-14_DeID', './data\\data_KNU_2020-09-17_DeID']

# %%
data_paths_diorco
# Out:
# ['./data\\data_KNU_2020-08-14_Diorco', './data\\data_KNU_2020-09-17_Diorco']

# %%
label_paths
# Out:
# ['./data\\data_KNU_2020-08-14_DeID\\label.xlsx',
#  './data\\data_KNU_2020-09-17_DeID\\label.xlsx']

# %%
img_paths_list = []
stl_paths_list = [] 
for data_path_diorco in data_paths_deid:
    img_paths = glob.glob(os.path.join(data_path_diorco, r'QH*'))
#     img_paths = sorted(img_paths)
    
#     print(len(img_paths))
    img_paths_list.extend(img_paths)
for stl_path in img_paths_list : 
    stl_paths = glob.glob(os.path.join(stl_path,'Files',r'*SO.stl'))
#     print(stl_paths)
    stl_paths_list.extend(stl_paths)

# %%
len(stl_paths_list)
# Out:
# 388

# %%
stl_paths_list
# Out:
# ['./data\\data_KNU_2020-08-14_DeID\\QH0026\\Files\\QH0026_01A1SO.stl',
#  './data\\data_KNU_2020-08-14_DeID\\QH0026\\Files\\QH0026_02B1SO.stl',
#  './data\\data_KNU_2020-08-14_DeID\\QH0041\\Files\\QH0041_01A1SO.stl',
#  './data\\data_KNU_2020-08-14_DeID\\QH0041\\Files\\QH0041_02B1SO.stl',
#  './data\\data_KNU_2020-08-14_DeID\\QH0044\\Files\\QH0044_02B1SO.stl',
#  './data\\data_KNU_2020-08-14_DeID\\QH0059\\Files\\QH0059_01A1SO.stl',
#  './data\\data_KNU_2020-08-14_DeID\\QH0059\\Files\\QH0059_02B1SO.stl',
#  './data\\data_KNU_2020-08-14_DeID\\QH0067\\Files\\QH0067_01A1SO.stl',
#  './data\\data_KNU_2020-08-14_DeID\\QH0067\\Files\\QH0067_02B1SO.stl',
#  './data\\data_KNU_2020-08-14_DeID\\QH0070\\Files\\QH0070_01A1SO.stl',
#  './data\\data_KNU_2020-08-14_DeID\\QH0070\\Files\\QH0070_02B1SO.stl',
#  './data\\data_KNU_2020-08-14_DeID\\QH0083\\Files\\QH0083_01A1SO.stl',
#  './data\\data_KNU_2020-08-14_DeID\\QH0093\\Files\\QH0093_02B1SO.stl',
#  './data\\data_KNU_2020-08-14_DeID\\QH0097\\Files\\QH0097_01A1SO.stl',
#  './data\\data_KNU_2020-08-14_DeID\\QH0097\\Files\\QH0097_02B1SO.stl',
#  './data\\data_KNU_2020-08-14_DeID\\QH0101\\Files\\QH0101_01A1SO.stl',
#  './data\\data_KNU_2020-08-14_DeID\\QH0101\\Files\\QH0101_02B1SO.stl',
#  './data\\data_KNU_2020-08-14_DeID\\QH0102\\Files\\QH0102_01A1SO.stl',
#  './data\\data_KNU_2020-08-14_DeID\\QH0102\\Files\\QH0102_02B1SO.stl',
#  './data\\data_KNU_2020-08-14_DeID\\QH0106\\Files\\QH0106_01A1SO.stl',
#  './data\\data_KNU_2020-08-14_DeID\\QH0106\\Files\\QH0106_02B1SO.stl',
#  './data\\data_KNU_2020-08-14_DeID\\QH0115\\Files\\QH0115_01A1SO.stl',
#  './data\\data_KNU_2020-08-14_DeID\\QH0115\\Files\\QH0115_02B1SO.stl',
#  './data\\data_KNU_2020-08-14_DeID\\QH0123\\Files\\QH0123_01A1SO.stl',
#  './data\\data_KNU_2020-08-14_DeID\\QH0123\\Files\\QH0123_02B1SO.stl',
#  './data\\data_KNU_2020-08-14_DeID\\QH0126\\Files\\QH0126_02B1SO.stl',
#  './data\\data_KNU_2020-08-14_DeID\\QH0129\\Files\\QH0129_01A1SO.stl',
#  './data\\data_KNU_2020-08-14_DeID\\QH0129\\Files\\QH0129_02B1SO.stl',
#  './data\\data_KNU_2020-08-14_DeID\\QH0145\\Files\\QH0145_01A1SO.stl',
#  './data\\data_KNU_2020-08-14_DeID\\QH0145\\Files\\QH0145_02B1SO.stl',
#  './data\\data_KNU_2020-08-14_DeID\\QH0153\\Files\\QH0153_01A1SO.stl',
#  './data\\data_KNU_2020-08-14_DeID\\QH0153\\Files\\QH0153_02B1SO.stl',
#  './data\\data_KNU_2020-08-14_DeID\\QH0158\\Files\\QH0158_01A1SO.stl',
#  './data\\data_KNU_2020-08-14_DeID\\QH0158\\Files\\QH0158_02B1SO.stl',
#  './data\\data_KNU_2020-08-14_DeID\\QH0162\\Files\\QH0162_02B1SO.stl',
#  './data\\data_KNU_2020-08-14_DeID\\QH0164\\Files\\QH0164_01A1SO.stl',
#  './data\\data_KNU_2020-08-14_DeID\\QH0164\\Files\\QH0164_02B1SO.stl',
#  './data\\data_KNU_2020-08-14_DeID\\QH0176\\Files\\QH0176_01A1SO.stl',
#  './data\\data_KNU_2020-08-14_DeID\\QH0176\\Files\\QH0176_02B1SO.stl',
#  './data\\data_KNU_2020-08-14_DeID\\QH0178\\Files\\QH0178_01A1SO.stl',
#  './data\\data_KNU_2020-08-14_DeID\\QH
02B1SO.stl',
#  './data\\data_KNU_2020-09-17_DeID\\QH1354\\Files\\QH1354_01A1SO.stl',
#  './data\\data_KNU_2020-09-17_DeID\\QH1354\\Files\\QH1354_02B1SO.stl',
#  './data\\data_KNU_2020-09-17_DeID\\QH1355\\Files\\QH1355_01A1SO.stl']

# %%
i=0

# %%
# Create a new plot
figure = plt.figure()
axes = mplot3d.Axes3D(figure)

# Load the STL file and add the vectors to the plot
stl_mesh = mesh.Mesh.from_file(stl_paths_list[i])
axes.add_collection3d(mplot3d.art3d.Poly3DCollection(stl_mesh.vectors))

# Auto scale to the mesh size
scale = stl_mesh.points.flatten('C')
axes.auto_scale_xyz(scale, scale, scale)

# Show the plot to the screen
plt.show()

# %%
output_path = os.path.splitext(os.path.basename(stl_paths_list[i]))[0] + r'_right.png'
output_path
# Out:
# 'QH0026_01A1SO_right.png'

# %%
i=2
stl_mesh = mesh.Mesh.from_file(stl_paths_list[i])

# Plot the mesh
vpl.mesh_plot(stl_mesh)

vpl.view(focal_point=(0.0, 0.0, 0.0), camera_position=(-1.0, 0.0, 0.0), camera_direction=None, up_view=(0.0, 1.0, 0.0))
vpl.reset_camera()

# Show the figure
# vpl.show()
output_path = os.path.join('./stl_jpg/',os.path.splitext(os.path.basename(stl_paths_list[i]))[0] + r'_right.png')
vpl.save_fig(output_path, pixels=(900, 900), off_screen=True)





vpl.view(focal_point=(0.0, 0.0, 0.0), camera_position=(1.0, 0.0, 0.0), camera_direction=None, up_view=(0.0, 1.0, 0.0))
vpl.reset_camera()
output_path = os.path.join('./stl_jpg/',os.path.splitext(os.path.basename(stl_paths_list[i]))[0] + r'_left.png')
vpl.save_fig(output_path, pixels=(900, 900), off_screen=True)

# %%
i=3
stl_mesh = mesh.Mesh.from_file(stl_paths_list[i])

# Plot the mesh
vpl.mesh_plot(stl_mesh)

vpl.view(focal_point=(0.0, 0.0, 0.0), camera_position=(-1.0, 0.0, 0.0), camera_direction=None, up_view=(0.0, 1.0, 0.0))
vpl.reset_camera()

# Show the figure
# vpl.show()
output_path = os.path.join('./stl_jpg/',os.path.splitext(os.path.basename(stl_paths_list[i]))[0] + r'_right.png')
vpl.save_fig(output_path, pixels=(900, 900), off_screen=True)





vpl.view(focal_point=(0.0, 0.0, 0.0), camera_position=(1.0, 0.0, 0.0), camera_direction=None, up_view=(0.0, 1.0, 0.0))
vpl.reset_camera()
output_path = os.path.join('./stl_jpg/',os.path.splitext(os.path.basename(stl_paths_list[i]))[0] + r'_left.png')
vpl.save_fig(output_path, pixels=(900, 900), off_screen=True)

# %%
for i in range(len(stl_paths_list)):
# Load the STL file
    stl_mesh = mesh.Mesh.from_file(stl_paths_list[i])

    # Plot the mesh
    vpl.mesh_plot(stl_mesh)

    vpl.view(focal_point=(0.0, 0.0, 0.0), camera_position=(-1.0, 0.0, 0.0), camera_direction=None, up_view=(0.0, 1.0, 0.0))
    vpl.reset_camera()

    # Show the figure
    # vpl.show()
    output_path = os.path.join('./stl_jpg/',os.path.splitext(os.path.basename(stl_paths_list[i]))[0] + r'_right.png')
    vpl.save_fig(output_path, pixels=(900, 900), off_screen=True)





    vpl.view(focal_point=(0.0, 0.0, 0.0), camera_position=(1.0, 0.0, 0.0), camera_direction=None, up_view=(0.0, 1.0, 0.0))
    vpl.reset_camera()
    output_path = os.path.join('./stl_jpg/',os.path.splitext(os.path.basename(stl_paths_list[i]))[0] + r'_left.png')
    vpl.save_fig(output_path, pixels=(900, 900), off_screen=True)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-16-38e8862b3099> in <module>
#       1 for i in range(len(stl_paths_list)):
#       2 # Load the STL file
# ----> 3     stl_mesh = mesh.Mesh.from_file(stl_paths_list[i])
#       4
#       5     # Plot the mesh
#
# ~\Anaconda3\lib\site-packages\stl\stl.py in from_file(cls, filename, calculate_normals, fh, mode, speedups, **kwargs)
#     339         else:
#     340             with open(filename, 'rb') as fh:
# --> 341                 name, data = cls.load(
#     342                     fh, mode=mode, speedups=speedups)
#     343
#
# ~\Anaconda3\lib\site-packages\stl\stl.py in load(cls, fh, mode, speedups)
#      93                     name, data = cls._load_binary(fh, header, check_size=True)
#      94         else:
# ---> 95             name, data = cls._load_binary(fh, header)
#      96
#      97         return name, data
#
# ~\Anaconda3\lib\site-packages\stl\stl.py in _load_binary(cls, fh, header, check_size)
#     106             count, = struct.unpack(s('<i'), b(count_data))
#     107         # raise RuntimeError()
# --> 108         assert count < MAX_COUNT, ('File too large, got %d triangles which '
#     109                                    'exceeds the maximum of %d') % (
#     110                                        count, MAX_COUNT)
#
# AssertionError: File too large, got 2009002018 triangles which exceeds the maximum of 100000000

# %%
vpl.shape
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-808672d06040> in <module>
# ----> 1 vpl.shape
#
# AttributeError: module 'vtkplotlib' has no attribute 'shape'

# %%
# Load the STL file
stl_mesh = mesh.Mesh.from_file(stl_paths_list[i])

# Plot the mesh
vpl.mesh_plot(stl_mesh)

# Set Camera position/orientation
vpl.view(focal_point=(0.0, 0.0, 0.0), camera_position=(-1.0, 0.0, 0.0), camera_direction=None, up_view=(0.0, 1.0, 0.0))
vpl.reset_camera()

# Show the figure
vpl.show()

# Save the figure
output_path = os.path.splitext(os.path.basename(stl_path))[0] + r'_right.png'
# vpl.save_fig(output_path, pixels=(900, 900), off_screen=True)

# Set Camera position/orientation
vpl.view(focal_point=(0.0, 0.0, 0.0), camera_position=(1.0, 0.0, 0.0), camera_direction=None, up_view=(0.0, 1.0, 0.0))
vpl.reset_camera()

# Show the figure
# vpl.show()

# Save the figure
output_path = os.path.splitext(os.path.basename(stl_path))[0] + r'_left.png'
# vpl.save_fig(output_path, pixels=(900, 900), off_screen=True)
