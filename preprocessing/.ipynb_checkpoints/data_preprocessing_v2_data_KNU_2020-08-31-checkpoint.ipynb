# %% [markdown]
# # Data Preprocessing
# ---
#
# * KNU data

# %%
import glob
import os
import pprint
from tqdm import tqdm
from sklearn.utils import Bunch

from IPython import display
import ipywidgets as widgets

# %matplotlib inline
from matplotlib import pyplot as plt
plt.style.use('seaborn-white')
import numpy as np
import pandas as pd
import seaborn as sns
sns.set_style('white')

import cv2 as cv

from jin import jin_utils

# %load_ext version_information
# %version_information matplotlib, numpy, pandas, seaborn, cv2, skimage
# Out:
# Software versions
# Python 3.7.5 64bit [MSC v.1916 64 bit (AMD64)]
# IPython 7.9.0
# OS Windows 10 10.0.18362 SP0
# matplotlib 3.1.1
# numpy 1.17.3
# pandas 0.25.2
# seaborn 0.9.0
# cv2 3.4.2
# skimage 0.15.0
# Mon Oct 05 07:40:24 2020 ¢¥eCN©öI¡¾©ö C¡ÍA¨ª¨öA

# %% [markdown]
# ## Dental Model Images with Angle Class
# ---
#
# * Images processed by Diorco labeling SW

# %% [markdown]
# ### Paths
# ---

# %%
data_path_root = r'C:\Users\bomsi\workspace\Malocclusion\malocclusion_data'

data_paths_deid = glob.glob(os.path.join(data_path_root, r'*_DeID'))
data_paths_deid = sorted(data_paths_deid)

jin_utils.print_paths(data_paths_deid)

data_paths_diorco = glob.glob(os.path.join(data_path_root, r'*_Diorco'))
data_paths_diorco = sorted(data_paths_diorco)

jin_utils.print_paths(data_paths_diorco)

label_paths = glob.glob(os.path.join(data_path_root, '*_DeID/label*'))
label_paths = sorted(label_paths)

jin_utils.print_paths(label_paths)
# Out:
# 2
# ['E:/datasets/projects/clear_aligner\\data_KNU_2020-08-14_DeID',
#  'E:/datasets/projects/clear_aligner\\data_KNU_2020-08-31_DeID']
# 2
# ['E:/datasets/projects/clear_aligner\\data_KNU_2020-08-14_Diorco',
#  'E:/datasets/projects/clear_aligner\\data_KNU_2020-08-31_Diorco']
# 2
# ['E:/datasets/projects/clear_aligner\\data_KNU_2020-08-14_DeID\\label.xlsx',
#  'E:/datasets/projects/clear_aligner\\data_KNU_2020-08-31_DeID\\label.xlsx']

# %% [markdown]
# ### Hyper-parameters
# ---

# %%
params = Bunch(resize_wh = (1920, 1039),
               crop_row_range = (332, 812),
               crop_col_size_half = 2**4 * 11)

for k, v in params.items():
    print(f'{k}: {v}')
# Out:
# resize_wh: (1920, 1039)
# crop_row_range: (332, 812)
# crop_col_size_half: 176

# %% [markdown]
# ### Images
# ---

# %%
img_paths_list = []

for data_path_diorco in data_paths_diorco:
    img_paths = glob.glob(os.path.join(data_path_diorco, r'*_SO_reori.jpg'))
#     img_paths = sorted(img_paths)
    
    print(len(img_paths))
    img_paths_list.extend(img_paths)
else:
    img_paths = img_paths_list
    del img_paths_list
    img_paths = sorted(img_paths)
    
    jin_utils.print_paths(img_paths)
# Out:
# 200
# 620
# 820
# ['E:/datasets/projects/clear_aligner\\data_KNU_2020-08-14_Diorco\\QH0026_01A1SU_SO_reori.jpg',
#  'E:/datasets/projects/clear_aligner\\data_KNU_2020-08-14_Diorco\\QH0026_02B1SU_SO_reori.jpg',
#  'E:/datasets/projects/clear_aligner\\data_KNU_2020-08-14_Diorco\\QH0041_01A1SU_SO_reori.jpg',
#  'E:/datasets/projects/clear_aligner\\data_KNU_2020-08-14_Diorco\\QH0041_02B1SU_SO_reori.jpg',
#  'E:/datasets/projects/clear_aligner\\data_KNU_2020-08-14_Diorco\\QH0044_01A1SU_SO_reori.jpg',
#  '...',
#  'E:/datasets/projects/clear_aligner\\data_KNU_2020-08-31_Diorco\\QH1245_02B1SU_SO_reori.jpg',
#  'E:/datasets/projects/clear_aligner\\data_KNU_2020-08-31_Diorco\\QH1248_01A1SU_SO_reori.jpg',
#  'E:/datasets/projects/clear_aligner\\data_KNU_2020-08-31_Diorco\\QH1248_02B1SU_SO_reori.jpg',
#  'E:/datasets/projects/clear_aligner\\data_KNU_2020-08-31_Diorco\\QH1250_01A1SU_SO_reori.jpg',
#  'E:/datasets/projects/clear_aligner\\data_KNU_2020-08-31_Diorco\\QH1250_02B1SU_SO_reori.jpg']

# %%
img = cv.imread(img_paths[0])
img = cv.cvtColor(img, cv.COLOR_BGR2RGB)

plt.figure()

plt.imshow(img)

plt.show()

# %% [markdown]
# ### Labels
# ---

# %%
label_df_list = []

for label_path in label_paths:
    label_df = pd.read_excel(label_path,
                         usecols=['Project_id', 'Tx', 'Phase', 'Angle_Class_Type_Right', 'Angle_Class_Type_Left'])

    print(label_df.shape)
    
    # Fill empty cells.
    for row_idx, project_id in enumerate(label_df.Project_id):
        if row_idx % 2 == 0:
            project_id_temp = project_id
        else:
            label_df.iloc[row_idx, 0] = project_id_temp
            
    label_df_list.append(label_df)
else:
    label_df = pd.concat(label_df_list)
    del(label_df_list)
    
    # Rename Columns.
    label_df.rename(columns={'Project_id': 'patient_id',
                             'Tx': 'tx',
                             'Phase': 'tx_phase',
                             'Angle_Class_Type_Right': 'angle_class_r',
                             'Angle_Class_Type_Left': 'angle_class_l'},
                    inplace=True)
    label_df.reset_index(drop=True, inplace=True)
    
    # Change some values.
    label_df.loc[label_df.tx_phase == 'Pre-treatment', 'tx_phase'] = 'Pre-Tx'
    label_df.loc[label_df.tx_phase == 'Post-treatment', 'tx_phase'] = 'Post-Tx'
    
    display.display(label_df.info())
    display.display(label_df)
    
    plt.style.use('seaborn-whitegrid')
    plt.figure()
    
    plt.title('Label')
    sns.countplot(np.concatenate([label_df.angle_class_r, label_df.angle_class_l]))

    plt.show()
# Out:
# (200, 5)
# (620, 5)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 820 entries, 0 to 819
# Data columns (total 5 columns):
# patient_id       820 non-null object
# tx               820 non-null int64
# tx_phase         820 non-null object
# angle_class_r    820 non-null int64
# angle_class_l    820 non-null int64
# dtypes: int64(3), object(2)
# memory usage: 32.2+ KB
# None
#     patient_id  tx tx_phase  angle_class_r  angle_class_l
# 0       QH0026   1   Pre-Tx              1              1
# 1       QH0026   1  Post-Tx              1              2
# 2       QH0041   1   Pre-Tx              2              1
# 3       QH0041   1  Post-Tx              2              1
# 4       QH0044   1   Pre-Tx              2              2
# ..         ...  ..      ...            ...            ...
# 815     QH1245   1  Post-Tx              1              1
# 816     QH1248   1   Pre-Tx              1              3
# 817     QH1248   1  Post-Tx              2              1
# 818     QH1250   1   Pre-Tx              2              2
# 819     QH1250   1  Post-Tx              2              2
#
# [820 rows x 5 columns]

# %% [markdown]
# ### Preprocessing
# ---

# %%
imgs = []
label_df_list = []

for img_path in tqdm(img_paths):
    data_info = os.path.basename(img_path)[:11]
    patient_id = data_info.split('_')[0]

    img = cv.imread(img_path)
    img = cv.cvtColor(img, cv.COLOR_BGR2RGB)

    if img.size > (params.resize_wh[0] * params.resize_wh[1]):
        img = cv.resize(img, params.resize_wh, interpolation=cv.INTER_AREA)
    else:
        print(f'{img_path}: Image size should be larger than ({params.resize_wh[1]}, {params.resize_wh[0]}).')
        raise
    
    col_idx_half = img.shape[1] // 2

    img = img[params.crop_row_range[0]:params.crop_row_range[1]]
    img_r = img[:, : col_idx_half - params.crop_col_size_half]
    img_l = img[:, col_idx_half + params.crop_col_size_half :]
    img_l = np.fliplr(img_l)
    img = np.concatenate((img_r, img_l), axis=2)

    if data_info[-2] == 'A':
        bool_mask = (label_df.patient_id == patient_id) & (label_df.tx_phase == 'Pre-Tx')
    elif data_info[-2] == 'B':
        bool_mask = (label_df.patient_id == patient_id) & (label_df.tx_phase == 'Post-Tx')
    label = [int(label_df[bool_mask].angle_class_r),
             int(label_df[bool_mask].angle_class_l)]
    
    # DEBUG:
#     print(f'{data_info}: {img.shape}, {label}')
    
    if 0 in label:
        continue
    
    imgs.append(img)
    label_df_list.append(label_df[bool_mask])
else:
    imgs = np.asarray(imgs)
    label_df = pd.concat(label_df_list)
    del label_df_list
    label_df.reset_index(drop=True, inplace=True)
    
    print(imgs.dtype, imgs.shape)
    print()
    display.display(label_df.info())
    display.display(label_df)
    print()
    
    plt.style.use('seaborn-whitegrid')
    plt.figure()
    
    plt.title('Label')
    sns.countplot(np.concatenate([label_df.angle_class_r, label_df.angle_class_l]))

    plt.show()
    plt.style.use('seaborn-white')
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 820/820 [00:30<00:00, 27.21it/s]
# uint8 (809, 480, 784, 6)
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 809 entries, 0 to 808
# Data columns (total 5 columns):
# patient_id       809 non-null object
# tx               809 non-null int64
# tx_phase         809 non-null object
# angle_class_r    809 non-null int64
# angle_class_l    809 non-null int64
# dtypes: int64(3), object(2)
# memory usage: 31.7+ KB
# None
#     patient_id  tx tx_phase  angle_class_r  angle_class_l
# 0       QH0026   1   Pre-Tx              1              1
# 1       QH0026   1  Post-Tx              1              2
# 2       QH0041   1   Pre-Tx              2              1
# 3       QH0041   1  Post-Tx              2              1
# 4       QH0044   1   Pre-Tx              2              2
# ..         ...  ..      ...            ...            ...
# 804     QH1245   1  Post-Tx              1              1
# 805     QH1248   1   Pre-Tx              1              3
# 806     QH1248   1  Post-Tx              2              1
# 807     QH1250   1   Pre-Tx              2              2
# 808     QH1250   1  Post-Tx              2              2
#
# [809 rows x 5 columns]

# %%
np.save(r'../data/data_KNU_Diorco_so_imgs.npy', imgs)
label_df.to_csv(r'../data/data_KNU_Diorco_so_img_labels.csv', index=False)
